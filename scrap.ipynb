# %%
# Import libraries for scraping and querying
from bs4 import BeautifulSoup 
import requests
import cohere

# Define list of Bible stories to focus on scraping
target_stories = [
  "Water into wine",
  "Feeding the 5000", 
  "The Prodigal Son",
  # etc add more stories here
] 

# Scrape an online Bible for the text of the target stories

url = "https://www.biblegateway.com/passage/?search=John+2" # sample URL
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# Parse soup to extract text of story 
# Capture text in a variable called story_text
# Repeat for other story URLs


# Preprocess scraped text - clean up formatting, normalize quotes etc.

# Set up Cohere API client
co = cohere.Client('q81O6CJT17c7qfSQc7U693xvFwAVf9rDhsjoHv2b') 

# Define a function to query text with Cohere

def query_cohere(text, question):
  response = co.generate(
    prompt=f'Text: {text}\n\nQuestion: {question}', 
    max_tokens=500,
    temperature=0.5
  )
  
  return response.generations[0].text

# Sample query
story_text = "<Scraped text of a bible story>" 
question = "What is this story about?"

ai_response = query_cohere(story_text, question)
print(ai_response)

# Log each story text and query/response pair for analysis
# Out:
#
# The story is about the prophet Elijah and the drought God sent as judgment on Israel during the reign of King Ahab and his evil wife, Jezebel. This is the story of how God used Elijah to end that drought and punish those who did not follow his commandments.
#
# The narrative begins with a drought that lasts three and a half years, a lengthy period that culminates in widespread famine throughout the land. Through his prophets, Elijah, and later Elisha, God reveals his power and secures the survival of the faithful relative to those who forsake His commandments.
#
# Throughout the narrative, God proves His power and authority over the forces of nature and the foreign gods that Jezebel tried to introduce into Israel. The people of Israel are compelled to choose between their foreign god Baal and the Lord who brought them out of Egypt and guided them throughout their wilderness journey.
#
# Ultimately, the people of Israel turn back to the Lord, ending the drought and famine that had plagued the land for three and a half years.
#
# This story reminds readers that the Lord is powerful and in control of all the forces of nature, and that He will not forget His people, even when they face difficult times as a result of their disobedience and faithlessness.

# %%
# Import libraries 
from bs4 import BeautifulSoup
import requests
import re

# Bible site to scrape
url = "https://www.biblegateway.com/passage/?search=John+2" # sample URL

# Scrape the page
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# Extract the story text
story_text = soup.find('div', class_='passage-text').get_text()
story_text
# Out:
# '\n\n Jesus Changes Water Into Wine2\xa0On the third day a wedding took place at Cana in Galilee.(A) Jesus’ mother(B) was there, 2\xa0and Jesus and his disciples had also been invited to the wedding. 3\xa0When the wine was gone, Jesus’ mother said to him, “They have no more wine.” 4\xa0“Woman,[a](C) why do you involve me?”(D) Jesus replied. “My hour(E) has not yet come.” 5\xa0His mother said to the servants, “Do whatever he tells you.”(F) 6\xa0Nearby stood six stone water jars, the kind used by the Jews for ceremonial washing,(G) each holding from twenty to thirty gallons.[b] 7\xa0Jesus said to the servants, “Fill the jars with water”; so they filled them to the brim. 8\xa0Then he told them, “Now draw some out and take it to the master of the banquet.”They did so, 9\xa0and the master of the banquet tasted the water that had been turned into wine.(H) He did not realize where it had come from, though the servants who had drawn the water knew. Then he called the bridegroom aside 10\xa0and said, “Everyone brings out the choice wine first and then the cheaper wine after the guests have had too much to drink; but you have saved the best till now.” 11\xa0What Jesus did here in Cana of Galilee was the first of the signs
target_stories = [
  "Water into wine",
  "Feeding the 5000", 
  "The Prodigal Son",
  # etc add more stories here
]

# Now we want to scrape a general site
bible_url = "https://www.biblegateway.com/passage/?search={}&version=NIV" 

# Scrape the page
page = requests.get(bible_url.format("John")) # sample URL
soup = BeautifulSoup(page.content, 'html.parser')

# Extract the story text
story_text = soup.find('div', class_='passage-text').get_text()

# Preprocess the text
story_text = story_text.replace('\n', ' ')
story_text = re.sub(r'\s+', ' ', story_text)
story_text = story_text.strip()

# Set up Cohere API client
co = cohere.Client('q81O6CJT17c7qfSQc7U693xvFwAVf9rDhsjoHv2b')

# Define a function to query text with Cohere
def query_cohere(text, question):
  response = co.generate(
    prompt=f'Text: {text}\n\nQuestion: {question}', 
    max_tokens=500,
    temperature=0.5
  )
  
  return response.generations[0].text

# Sample query
story_text = 'Water into wine.'
question = "What is this story about? What is the moral?"

ai_response = query_cohere(story_text, question)
print(ai_response)
# Out:
#  The story of the transformation of water into wine at the wedding at Cana is recorded in the Gospel of John, and it is one of the few miracles attributed to Jesus in the New Testament.
#
# This event is recounted in John 2:1-11. Jesus was at a wedding celebration with his mother Mary, and his disciples. At some point, the wine provided for the celebration runs out, and Mary approaches Jesus with this problem, informing him of the shortage. Jesus responds by asking his mother for the servants' attention, and he has them fill six stone water jars with water and take some to the master of the feast. The water turned into wine upon tasting, and the master of the feast praised the groom for saving the best wine for last.
#
# The significance of this event is not just the miraculous transformation of water into wine, but it is often seen as an indication of Jesus' power and his willingness to intervene directly in people's lives, providing abundance and joy. On a spiritual level, it is also sometimes interpreted as a symbol of Jesus transforming the humble elements of everyday life into something of higher value, paralleling his later teachings and the promise of salvation through him. The exact moral of the story could be:
#
# 1. Have faith and understand that Jesus is willing and able to provide miracles
# 2. Request help from Jesus, and he will provide
# 3. Jesus cares about the little details of your life and will provide joy
#
# Ultimately, as with many stories and parables in the Bible, there is room for interpretation, and people draw different lessons and meanings from this event based on their individual faith and perspective.

# %%
# Import libraries
from bs4 import BeautifulSoup
import requests
import re
import cohere

# Bible story URLs to scrape
story_urls = [
  "https://www.biblegateway.com/passage/?search=John+2&version=NIV", # Water to wine
  "https://www.biblegateway.com/passage/?search=matthew+14%3A13-21&version=NIV", # Feeding 5000
  "https://www.biblegateway.com/passage/?search=luke+15%3A11-32&version=NIV", # Prodigal son
]

# Extract story text from page
def scrape_story(url):
  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')
  text = soup.find('div', class_='passage-text').get_text()
  
  # Clean text
  text = re.sub(r"\[(.*?)\]", "", text) # Remove [ ]
  text = re.sub("\s+", " ", text) # Normalize whitespace
  
  return text

# Scrape all stories  
stories = {}
for url in story_urls:
  name = url.split("=")[1] # Get story name from URL
  stories[name] = scrape_story(url) 

# Print stories
for key, story in stories.items():
  print(key)
  print(story)
  print()

# Setup Cohere
co = cohere.Client('q81O6CJT17c7qfSQc7U693xvFwAVf9rDhsjoHv2b')

# Query function
def query_cohere(story_text, question):
  response = co.generate(
    prompt=f"Story: {story_text}\nQuestion: {question}",
    max_tokens=500,
  )

  return response.generations[0].text 

# Sample query
key = "John+2&version"
query = "What is the moral of this story?"
ai_response = query_cohere(stories[key], query)
print(ai_response)

# Log responses
story_logs = {}

for key, story in stories.items():
  query = "Where did it happen? What is the moral of this story?"
  response = query_cohere(story, query)
  
  story_logs[key] = {
    "story": story, 
    "questions": [query],
    "responses": [response]
  }
  
print(story_logs)
# Out:
# John+2&version
#  Jesus Changes Water Into Wine2 On the third day a wedding took place at Cana in Galilee.(A) Jesus’ mother(B) was there, 2 and Jesus and his disciples had also been invited to the wedding. 3 When the wine was gone, Jesus’ mother said to him, “They have no more wine.” 4 “Woman,(C) why do you involve me?”(D) Jesus replied. “My hour(E) has not yet come.” 5 His mother said to the servants, “Do whatever he tells you.”(F) 6 Nearby stood six stone water jars, the kind used by the Jews for ceremonial washing,(G) each holding from twenty to thirty gallons. 7 Jesus said to the servants, “Fill the jars with water”; so they filled them to the brim. 8 Then he told them, “Now draw some out and take it to the master of the banquet.”They did so, 9 and the master of the banquet tasted the water that had been turned into wine.(H) He did not realize where it had come from, though the servants who had drawn the water knew. Then he called the bridegroom aside 10 and said, “Everyone brings out the choice wine first and then the cheaper wine after the guests have had too much to drink; but you have saved the best till now.” 11 What Jesus did here in Cana of Galilee was the first of the signs(I) through which he revealed his glory;(J) and his disciples believed in him.(K) 12 After this he went down to Capernaum(L) with his mother(M) and brothers(N) and his disciples. There they stayed for a few days. Jesus Clears the Temple Courts(O)13 When it was almost time for the Jewish Passover,(P) Jesus went up to Jerusalem.(Q) 14 In the temple courts he found people selling cattle, sheep and doves,(R) and others sitting at tables exchanging money.(S) 15 So he made a whip out of cords, and drove all from the temple courts, both sheep and cattle; he scattered the coins of the money changers and overturned their tables. 16 To those who sold doves he said, “Get these out of here! Stop turning my Father’s house(T) into a market!” 17 His disciples remembered that it is written: “Zeal for your house will consume me.”(U) 18 The Jews(V) then responded to him, “What sign(W) can you show us to prove your authority to do all this?”(X) 19 Jesus answered them, “Destroy this temple, and I will raise it again in three days.”(Y) 20 They replied, “It has taken forty-six years to build this temple, and you are going to raise it in three days?” 21 But the temple he had spoken of was his body.(Z) 22 After he was raised from the dead, his disciples recalled what he had said.(AA) Then they believed the scripture(AB) and the words that Jesus had spoken. 23 Now while he was in Jerusalem at the Passover Festival,(AC) many people saw the signs(AD) he was performing and believed(AE) in his name. 24 But Jesus would not entrust himself to them, for he knew all people. 25 He did not need any testimony about mankind,(AF) for he knew what was in each person.(AG) FootnotesJohn 2:4 The Greek for Woman does not denote any disrespect. John 2:6 Or from about 75 to about 115 liters John 2:17 Psalm 69:9 John 2:23 Or in him Cross referencesJohn 2:1 : Jn 4:46; 21:2 John 2:1 : S Mt 12:46 John 2:4 : Jn 19:26 John 2:4 : S Mt 8:29 John 2:4 : S Mt 26:18 John 2:5